# %% [markdown]
# # Pandas && Census Analysis
#
# Pandas is a Python library that makes handling tabular data easier.
#
# ## Pandas
# Pandas gives "Data Frames" and "Series" that allow the user to slice and dice rows and columns of information.
#
# ## Already some Data-Prep
# - redundant text has been removed ('estimated', && 'Population for whom poverty status is determined')
# - 'extra' header has been removed
#
# ## NumPy
# "NumPy arrays" are multi-dimensional array objects. It is easy to create a Pandas DataFrame from a NumPy array, and Pandas DataFrames can be cast as NumPy arrays.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd

# save file-data to var, using pandas read_file method
# assign to a DataFrame
df = pd.read_csv("./cleaned.csv")

# output a short-exampe of the data
df.head()
# Out:
#             id Geographic Area Name    Total:  Below poverty level:  \
# 0  0400000US02               Alaska    720869                 78620
# 1  0400000US23                Maine   1301941                151541
# 2  0400000US37       North Carolina  10100431               1417873
# 3  0400000US29             Missouri   5943658                786330
# 4  0400000US42         Pennsylvania  12394000               1517870
#
#    Percent below poverty level:  Total:AGE:Under 18 years  \
# 0                          10.9                    180258
# 1                          11.6                    240662
# 2                          14.0                   2257634
# 3                          13.2                   1347491
# 4                          12.2                   2594554
#
#    Below poverty level:AGE:Under 18 years  \
# 0                                   25327
# 1                                   34878
# 2                                  455971
# ...

# %% [markdown]
# # Head
# ... is a handy way to visualize a snippet what's been loaded. Head can also take an integer to see some specific number of rows at the beginning of the Pandas DataFrame:

# %%
df.head(8)
# Out:
#             id Geographic Area Name    Total:  Below poverty level:  \
# 0  0400000US02               Alaska    720869                 78620
# 1  0400000US23                Maine   1301941                151541
# 2  0400000US37       North Carolina  10100431               1417873
# 3  0400000US29             Missouri   5943658                786330
# 4  0400000US42         Pennsylvania  12394000               1517870
# 5  0400000US26             Michigan   9774124               1373349
# 6  0400000US31             Nebraska   1875342                206341
# 7  0400000US41               Oregon   4113142                516570
#
#    Percent below poverty level:  Total:AGE:Under 18 years  \
# 0                          10.9                    180258
# 1                          11.6                    240662
# 2                          14.0                   2257634
# 3                          13.2                   1347491
# 4                          12.2                   2594554
# ...

# %% [markdown]
# # Tail
# ... returns the END snippet of a dataset
# ... can also take an integer for number-of-rows

# %%
df.tail(4)
# Out:
#              id  Geographic Area Name   Total:   Below poverty level:   \
# 48  0400000US25         Massachusetts   6665083                 663918
# 49  0400000US11  District of Columbia    669031                 108055
# 50  0400000US49                  Utah   3110944                 280773
# 51  0400000US36              New York  19037564                2591391
#
#     Percent below poverty level:   Total: AGE: Under 18 years  \
# 48                           10.0                     1345037
# 49                           16.2                      125590
# 50                            9.0                      919114
# 51                           13.6                     3993286
#
#     Below poverty level: AGE: Under 18 years  \
# 48                                    163788
# 49                                     29048
# 50                                     87445
# 51                                    743024
#
#     Percent below poverty level: AGE: Under 18 years  \
# ...

# %% [markdown]
# # Shape
# The data's dimensions. ```[rowCount, columnCount]```

# %%
df.shape
# Out:
# (52, 137)

# %% [markdown]
# # Size
# the # of cells

# %%
df.size
# Out:
# 7124

# %% [markdown]
# # len
# the number of rows

# %%
len(df)
# Out:
# 52

# %% [markdown]
# # Columns
# ...

# %%
df.columns
# Out:
# Index(['id', 'Geographic Area Name', 'Total:', 'Below poverty level:',
#        'Percent below poverty level:', 'Total:AGE:Under 18 years',
#        'Below poverty level:AGE:Under 18 years',
#        'Percent below poverty level:AGE:Under 18 years',
#        'Total:AGE:Under 18 years!!Under 5 years',
#        'Below poverty level:AGE:Under 18 years!!Under 5 years',
#        ...
#        'Percent below poverty level:ALL INDIVIDUALS WITH INCOME BELOW THE FOLLOWING POVERTY RATIOS:200 percent of poverty level',
#        'Total:ALL INDIVIDUALS WITH INCOME BELOW THE FOLLOWING POVERTY RATIOS:300 percent of poverty level',
#        'Below poverty level:ALL INDIVIDUALS WITH INCOME BELOW THE FOLLOWING POVERTY RATIOS:300 percent of poverty level',
#        'Percent below poverty level:ALL INDIVIDUALS WITH INCOME BELOW THE FOLLOWING POVERTY RATIOS:300 percent of poverty level',
#        'Total:ALL INDIVIDUALS WITH INCOME BELOW THE FOLLOWING POVERTY RATIOS:400 percent of poverty level',
# ...

# %% [markdown]
# # Single Column (Series)

# %%
df['Percent below poverty level:']
# Out:
# 0     10.9
# 1     11.6
# 2     14.0
# 3     13.2
# 4     12.2
# 5     14.1
# 6     11.0
# 7     12.6
# 8     11.1
# 9     12.8
# 10    19.7
# 11    10.4
# 12    14.9
# 13    11.8
# 14     9.0
# 15    19.5
# 16    16.8
# 17    15.3
# 18    11.0
# 19    12.9
# 20    17.8
# 21    15.6
# 22    11.0
# 23    43.1
# 24    12.0
# 25    10.7
# 26    10.7
# 27     9.5
# 28    13.9
# 29    15.3
# 30    14.3
# 31     9.6
# 32     8.8
# 33    13.1
# 34    13.1
# 35    16.9
# 36    18.6
# 37    10.3
# 38    12.1
# 39    11.2
# 40     7.6
# 41    12.9
# 42    17.2
# 43    12.5
# 44     9.6
# 45    13.0
# 46    14.0
# 47    13.6
# 48    10.0
# 49    16.2
# 50     9.0
# 51    13.6
# Name: Percent below poverty level:, dtype: float64

# %% [markdown]
# # Specific range from series

# %%
df['Percent below poverty level:'][:5]
# Out:
# 0    10.9
# 1    11.6
# 2    14.0
# 3    13.2
# 4    12.2
# Name: Percent below poverty level:, dtype: float64

# %% [markdown]
# # Single element from series

# %%
df['Percent below poverty level:'][5]
# Out:
# 14.1

# %% [markdown]
# # Multiple Series

# %%
df[['Percent below poverty level:', 'Percent below poverty level:AGE:Under 18 years']]
# Out:
#     Percent below poverty level:  \
# 0                           10.9
# 1                           11.6
# 2                           14.0
# 3                           13.2
# 4                           12.2
# 5                           14.1
# 6                           11.0
# 7                           12.6
# 8                           11.1
# 9                           12.8
# 10                          19.7
# 11                          10.4
# 12                          14.9
# 13                          11.8
# 14                           9.0
# 15                          19.5
# 16                          16.8
# 17                          15.3
# 18                          11.0
# 19                          12.9
# 20                          17.8
# 21                          15.6
# 22                          11.0
# 23                          43.1
# 24                          12.0
# 25                          10.7
# 26                          10.7
# ...

# %% [markdown]
# # Range from muti-series

# %%
df[['Percent below poverty level:', 'Percent below poverty level:AGE:Under 18 years']][:5]
# Out:
#    Percent below poverty level:  \
# 0                          10.9
# 1                          11.6
# 2                          14.0
# 3                          13.2
# 4                          12.2
#
#    Percent below poverty level:AGE:Under 18 years
# 0                                            14.1
# 1                                            14.5
# 2                                            20.2
# 3                                            18.3
# 4                                            16.8

# %% [markdown]
# Sorting your DataFrame by a specific column looks like this:

# %%
df.sort_values(['Percent below poverty level:'])
# Out:
#              id  Geographic Area Name    Total:  Below poverty level:  \
# 40  0400000US33         New Hampshire   1312006                100220
# 32  0400000US15                Hawaii   1382448                122143
# 50  0400000US49                  Utah   3110944                280773
# 14  0400000US24              Maryland   5899819                528203
# 27  0400000US34            New Jersey   8739304                832133
# 44  0400000US27             Minnesota   5488344                529077
# 31  0400000US08              Colorado   5577020                537492
# 48  0400000US25         Massachusetts   6665083                663918
# 37  0400000US53            Washington   7400557                759013
# 11  0400000US09           Connecticut   3468263                361377
# 25  0400000US51              Virginia   8264095                884647
# 26  0400000US38          North Dakota    736671                 78676
# ...

# %% [markdown]
# You can break down the number of unique values in a given column into a Series using value_counts() - this is a good way to understand the distribution of your data:

# %%
degree_counts = df['Level of Education'].value_counts()
degree_counts
# Out:
# BS     7
# PhD    4
# MS     2
# Name: Level of Education, dtype: int64

# %% [markdown]
# Pandas even makes it easy to plot a Series or DataFrame - just call plot():

# %%
degree_counts.plot(kind='bar')

# %% [markdown]
# ## Exercise
#
# Try extracting rows 5-10 of our DataFrame, preserving only the "Previous Employers" and "Hired" columns. Assign that to a new DataFrame, and create a histogram plotting the distribution of the previous employers in this subset of the data.

# %%
prevHired = df[['Previous employers', 'Hired']]
prevHired
# Out:
#     Previous employers Hired
# 0                    4     Y
# 1                    0     Y
# 2                    6     N
# 3                    1     Y
# 4                    2     N
# 5                    0     Y
# 6                    2     Y
# 7                    1     Y
# 8                    5     Y
# 9                    0     N
# 10                   1     N
# 11                   1     Y
# 12                   0     Y

# %%
groupedByEmployerCount = df['Previous employers'].value_counts()
groupedByEmployerCount
# Out:
# 1    4
# 0    4
# 2    2
# 6    1
# 5    1
# 4    1
# Name: Previous employers, dtype: int64

# %%
groupedByEmployerCount.plot(kind='bar')
